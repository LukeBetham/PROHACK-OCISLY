# %%
import pandas as pd
import numpy as np

# ^^^ pyforest auto-imports - don't write above this line


from sklearn.model_selection import TimeSeriesSplit
from scipy import stats
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.impute import KNNImputer

# %%
import pandas as pd
import numpy as np
# ^^^ pyforest auto-imports - don't write above this line
#FINALLY WORKING

df = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
df["train_test"] = 'train'
df_test["train_test"] = "test"

print(df.shape)
print(df_test.shape)

df_combined = pd.concat([df,df_test])
print(df_combined.shape)
# Out:
# (3865, 81)
# (890, 80)
# (4755, 81)
# /Users/Tiffany/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.

# %%
#Creating copy of combined dataset with reset index

df_combined_1 = df_combined.copy()
df_combined_1.reset_index(inplace=True,drop=False)
df_combined_1.drop("index", axis=1, inplace=True)
df_combined_1
# Out:
#       Adjusted net savings   \
# 0                       NaN
# 1                 19.177926
# 2                 21.151265
# 3                       NaN
# 4                       NaN
# ...                     ...
# 4750                    NaN
# 4751                    NaN
# 4752                    NaN
# 4753                    NaN
# 4754                    NaN
#
#       Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 0                                            174.617899
# 1                                            109.892385
# 2                                            230.573666
# 3                                            198.971328
# 4                                             61.008654
# ...                                                 ...
# 4750                                                NaN
# 4751                                                NaN
# 4752                                                NaN
# ...

# %%
#Fitting galactic year to date time format

df_combined['galactic year 1'] = df_combined['galactic year'].apply(lambda x:(np.round((x/1000),0))*2)
df_combined['galactic year 1'] = df_combined['galactic year 1'].astype('int64')
df_combined['galactic year 1'] = df_combined['galactic year 1'].astype('str')
df_combined['galactic year 1'] = df_combined['galactic year 1'] + "0101"
df_combined['date'] = pd.to_datetime(df_combined['galactic year 1'], yearfirst=True
                                 , format='%Y/%m/%d'
                                )
df_combined.head()
# Out:
#    Adjusted net savings   \
# 0                    NaN
# 1              19.177926
# 2              21.151265
# 3                    NaN
# 4                    NaN
#
#    Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 0                                         174.617899
# 1                                         109.892385
# 2                                         230.573666
# 3                                         198.971328
# 4                                          61.008654
#
#    Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total  \
# 0                                                NaN
# 1                                                NaN
# 2                                           6.534020
# 3                                           5.912194
# 4                                           5.611753
#
#    Current health expenditure (% of GGP)  \
# 0                                    NaN
# ...

# %%
df_combined.train_test.value_counts()
# Out:
# train    3865
# test      890
# Name: train_test, dtype: int64

# %%
#ONLY USING FIRST 3 GALAXY

# mask = ((df_combined['galaxy']=='Large Magellanic Cloud (LMC)')
#         |(df_combined['galaxy']=='Camelopardalis B')
#         |(df_combined['galaxy']=='Virgo I')
#        )
# df_combined = df_combined[mask]
# df_combined

# %%
results_df = pd.DataFrame(columns = ['index', 'Adjusted net savings ',
       'Adolescent birth rate (births per 1,000 female creatures ages 15-19)',
       'Current health expenditure (% of GGP)',
       'Domestic credit provided by financial sector (% of GGP)',
       'Education Index', 'Employment in agriculture (% of total employment)',
       'Employment in services (% of total employment)',
       'Employment to population ratio (% ages 15 and older)',
       'Estimated gross galactic income per capita, female',
       'Estimated gross galactic income per capita, male',
       'Expected years of education (galactic years)',
       'Expected years of education, female (galactic years)',
       'Expected years of education, male (galactic years)',
       'Exports and imports (% of GGP)', 'Gender Development Index (GDI)',
       'Gender Inequality Index (GII)', 'Gross capital formation (% of GGP)',
       'Gross enrolment ratio, primary (% of primary under-age population)',
       'Gross fixed capital formation (% of GGP)',
       'Gross galactic product (GGP) per capita',
       'Gross galactic product (GGP), total', 'Gross income per capita',
       'Income Index',
       'Infants lacking immunization, Combination Vaccine (% of one-galactic year-olds)',
       'Infants lacking immunization, red hot disease (% of one-galactic year-olds)',
       'Intergalactic Development Index (IDI)',
       'Intergalactic Development Index (IDI), Rank',
       'Intergalactic Development Index (IDI), female',
       'Intergalactic Development Index (IDI), female, Rank',
       'Intergalactic Development Index (IDI), male',
       'Intergalactic Development Index (IDI), male, Rank',
       'Intergalactic inbound tourists (thousands)',
       'Interstellar Data Net users, total (% of population)',
       'Interstellar phone subscriptions (per 100 people)',
       'Jungle area (% of total land area)',
       'Labour force participation rate (% ages 15 and older)',
       'Labour force participation rate (% ages 15 and older), female',
       'Labour force participation rate (% ages 15 and older), male',
       'Life expectancy at birth, female (galactic years)',
       'Life expectancy at birth, male (galactic years)',
       'Maternal mortality ratio (deaths per 100,000 live births)',
       'Mean years of education (galactic years)',
       'Mean years of education, female (galactic years)',
       'Mean years of education, male (galactic years)',
       'Mortality rate, female grown up (per 1,000 people)',
       'Mortality rate, infant (per 1,000 live births)',
       'Mortality rate, male grown up (per 1,000 people)',
       'Mortality rate, under-five (per 1,000 live births)',
       'Natural resource depletion',
       'Old age dependency ratio (old age (65 and older) per 100 creatures (ages 15-64))',
       'Outer Galaxies direct investment, net inflows (% of GGP)',
       'Population using at least basic drinking-water services (%)',
       'Population using at least basic sanitation services (%)',
       'Population with at least some secondary education (% ages 25 and older)',
       'Population with at least some secondary education, female (% ages 25 and older)',
       'Population with at least some secondary education, male (% ages 25 and older)',
       'Population, ages 15–64 (millions)',
       'Population, ages 65 and older (millions)',
       'Population, total (millions)', 'Population, under age 5 (millions)',
       'Population, urban (%)', 'Remittances, inflows (% of GGP)',
       'Renewable energy consumption (% of total final energy consumption)',
       'Respiratory disease incidence (per 100,000 people)',
       'Rural population with access to electricity (%)',
       'Share of employment in nonagriculture, female (% of total employment in nonagriculture)',
       'Share of seats in senate (% held by female)',
       'Total unemployment rate (female to male ratio)',
       'Unemployment, total (% of labour force)',
       'Unemployment, youth (% ages 15–24)',
       'Vulnerable employment (% of total employment)',
       'Young age (0-14) dependency ratio (per 100 creatures ages 15-64)',
       'Youth unemployment rate (female to male ratio)',
       'existence expectancy at birth', 'existence expectancy index',
       'galactic year', 
                                     #'date',
       'Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total',
       'galaxy', 'train_test', 'y', 'Private galaxy capital flows (% of GGP)'])

# %%
#Imputing nans with time series - trying on one galaxy

success_list=[]


for g in df_combined.galaxy.unique():
    print(g)
    df_temp = df_combined[df_combined['galaxy']==g].copy()
    df = df_combined[~(df_combined['galaxy']==g)]
    #filling the Nans (first with interpolation and then backfilling if missing for start)
    df_temp.sort_values("galactic year",inplace=True)
    df_temp_1 = df_temp.copy()
    df_temp_1.drop(['galaxy','train_test','y','galactic year 1'
                    #'galactic year'
                   ],axis=1,inplace=True)
    df_temp_1.reset_index(inplace=True)
    null_list = [col for col in df_temp_1.columns if df_temp_1[col].isnull().all()]
    for n in null_list:
        df_temp_1.drop(columns=n, axis=1, inplace=True)
    
    print(null_list)
    
    for p in df_temp_1.columns:
        
        bool_series = list(pd.isnull(df_temp_1[p]))
        
        if p!='date' and (bool_series.count(False) > 1):
            try:
                df_temp_temp_1 = df_temp_1[['date',p]].copy()
                df_temp_temp_1.set_index('date', inplace=True, drop=True)
                data = df_temp_temp_1
                #print(p)
                model = sm.tsa.statespace.SARIMAX(data, order=(1, 0, 0))
                #print("model initiated")
                results = model.fit(maxiter=5000)
                
                bool_series = pd.isnull(df_temp_1[p]) 


                for q in df_temp_1.index:
                    if bool_series[q]==True and list(results.fittedvalues)[q]!=0:
                        df_temp_1[p].loc[q] = list(results.fittedvalues)[q]
                    else:
                        df_temp_1[p].loc[q]=df_temp_1[p].loc[q]
            except:
                error_list.append(g)
                print(p)
                
                
                for q in df_temp_1.index:
                    if bool_series[q]==True and list(results.fittedvalues)[q]!=0:
                        df_temp_1[p].loc[q] = df_temp_1[p].mean()
                    else:
                        df_temp_1[p].loc[q]=df_temp_1[p].loc[q]
    
    
    imputer = KNNImputer(n_neighbors=2, weights="distance")
    df_temp_1.drop(columns=['date'],inplace=True)
    df_temp_1 = df_temp_1.astype('float')
    df_temp_1 = pd.DataFrame(imputer.fit_transform(df_temp_1), columns = df_temp_1.columns)
                
    for n in null_list:
        df_temp_1[n]=list(df_temp[n])
        df_temp_1['galaxy'] = list(df_temp['galaxy'])
        df_temp_1['train_test'] = list(df_temp['train_test'])
        df_temp_1['y'] = list(df_temp['y'])


        #results_df = pd.concat([results_df,df_temp_temp])
    
    success_list.append(g)
    df = pd.concat([df,df_temp_1])
    results_df = pd.concat([results_df,df_temp_1])
    

#filling the Nans for any which didnt have anything to fill at all

#df.fillna(df.mean(),inplace=True)

for r in results_df.columns:
    if results_df[r].dtypes == 'float64':
        results_df[r].fillna(results_df[r].mean(),inplace=True)
        
for r in df.columns:
    if df[r].dtypes == 'float64':
        df[r].fillna(df[r].mean(),inplace=True)
    
#results_df.fillna(results_df.mean(),inplace=True)
# Out:
# Large Magellanic Cloud (LMC)
# ['Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total', 'Private galaxy capital flows (% of GGP)']
# /Users/Tiffany/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency 2AS-JAN will be used.
#   % freq, ValueWarning)
# /Users/Tiffany/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:205: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_with_indexer(indexer, value)
# /Users/Tiffany/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:165: ValueWarning: No frequency information was provided, so inferred frequency 2AS-JAN will be used.
#   % freq, ValueWarning)
# ...

# %%
error_list
# Out:
# []

# %%
df.shape
# Out:
# (4755, 84)

# %%
results_df.shape
# Out:
# (4755, 82)

# %% [markdown]
# # Results (time series -> knn impute -> fillna with mean (after merging)

# %%
df_combined[df_combined.galaxy=='NGC 5102'].sort_values(by='galactic year 1')
# Out:
#       Adjusted net savings   \
# 180               16.906874
# 226                     NaN
# 437                     NaN
# 690                     NaN
# 755                     NaN
# 1021              22.010527
# 1188                    NaN
# 1340                    NaN
# 1467                    NaN
# 1779                    NaN
# 1935              17.206781
# 2141                    NaN
# 2201                    NaN
# 2360                    NaN
# 2563                    NaN
# 2848              21.679276
# 3040                    NaN
# 782                     NaN
# 687                     NaN
# 824                     NaN
# 804               26.583421
# 819               19.621259
# 3512              15.240960
# 3610              17.145098
# 771               19.753047
# 812                9.882289
# 616               22.494515
#
#       Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 180                                           83.253063
# ...

# %%
df[df.galaxy=='NGC 5102'].sort_values(by='galactic year 1')
# Out:
#     Adjusted net savings   \
# 0               16.906874
# 1               16.163341
# 2               15.452508
# 3               14.772935
# 4               14.123249
# 5               22.010527
# 6               21.042545
# 7               20.117134
# 8               19.232420
# 9               18.386614
# 10              17.206781
# 11              16.450059
# 12              15.726617
# 13              15.034990
# 14              14.373779
# 15              21.679276
# 16              20.725862
# 17              19.814378
# 18              18.942979
# 19              18.109902
# 20              26.583421
# 21              19.621259
# 22              15.240960
# 23              17.145098
# 24              19.753047
# 25               9.882289
# 26              22.494515
#
#     Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 0                                           83.253063
# 1                                           81.007280
# ...

# %%
pd.DataFrame(df.isna().sum()).sort_values(by=0,ascending=False)
# Out:
#                                                      0
# galactic year 1                                     27
# date                                                27
# Adjusted net savings                                 0
# Population using at least basic drinking-water ...   0
# Population, under age 5 (millions)                   0
# ...                                                 ..
# Intergalactic Development Index (IDI)                0
# Infants lacking immunization, red hot disease (...   0
# Infants lacking immunization, Combination Vacci...   0
# Income Index                                         0
# y                                                    0
#
# [84 rows x 1 columns]

# %%
df.drop(columns=['galactic year 1','date'], inplace=True)

# %%
test = pd.read_csv('test.csv')
[col for col in df.columns if col not in test.columns]
#[col for col in test.columns if col not in results_df.columns]
# Out:
# ['index', 'train_test', 'y']

# %%
df['galaxy'].value_counts()
# Out:
# Donatiello I               27
# Andromeda VIII             27
# Sextans B (UGC 5373)       27
# Cetus Dwarf                27
# Aquarius II                27
#                            ..
# Triangulum Galaxy (M33)    25
# KKh 086                    24
# Hercules Dwarf             23
# Andromeda XVIII[60]        22
# NGC 5253                    1
# Name: galaxy, Length: 181, dtype: int64

# %%
df.set_index('index',inplace=True)

# %%
df.head()
# Out:
#    Adjusted net savings   \
# 0              20.990668
# 1              19.177926
# 2              21.151265
# 3              20.990668
# 4              20.990668
#
#    Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 0                                         174.617899
# 1                                         109.892385
# 2                                         230.573666
# 3                                         198.971328
# 4                                          61.008654
#
#    Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total  \
# 0                                           6.305201
# 1                                           6.305201
# 2                                           6.534020
# 3                                           5.912194
# 4                                           5.611753
#
#    Current health expenditure (% of GGP)  \
# 0                               8.881766
# ...

# %%
df_combined_a = df_combined[['galaxy','galactic year','train_test']]
df_combined_a['galplusyr'] = df_combined_a['galaxy']+df_combined_a['galactic year'].astype('str')
df_combined_a.rename(columns={"train_test":"train_test_org"},inplace=True)
df_combined_a.drop(['galaxy','galactic year'],axis=1,inplace=True)
df_combined_a_sort = df_combined_a.sort_values(by='galplusyr')
df_combined_a_sort
# Out:
# /Users/Tiffany/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#      train_test_org                                   galplusyr
# 1820          train               Andromeda Galaxy (M31)1000000
# 2003          train               Andromeda Galaxy (M31)1001000
# 2198          train               Andromeda Galaxy (M31)1002001
# 2416          train               Andromeda Galaxy (M31)1003002
# 2606          train               Andromeda Galaxy (M31)1004004
# ...             ...                                         ...
# 959           train  Wolf-Lundmark-Melotte (WLM, DDO 221)995006
# 1082          train  Wolf-Lundmark-Melotte (WLM, DDO 221)996004
# ...

# %%
df_a = df
df_a['galplusyr'] = df_a['galaxy']+df_a['galactic year'].astype('int').astype('str')
df_a_sort = df_a.sort_values(by='galplusyr')
df_a_sort
# Out:
#       Adjusted net savings   \
# 1820              20.990668
# 2003              20.990668
# 2198              20.990668
# 2416              20.990668
# 2606              20.990668
# ...                     ...
# 959                4.618121
# 1082              20.990668
# 1283              20.990668
# 1620              20.990668
# 1722              20.990668
#
#       Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 1820                                          84.826552
# 2003                                         109.537364
# 2198                                         109.537364
# 2416                                         109.537364
# 2606                                         109.537364
# ...                                                 ...
# 959                                          270.067153
# 1082                                         109.537364
# 1283                                         109.537364
# ...

# %%
df_a_sort['index'] = list(df_combined_a_sort.index)
df_a_sort.isna().sum()
# Out:
# Adjusted net savings                                                         0
# Adolescent birth rate (births per 1,000 female creatures ages 15-19)         0
# Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total    0
# Current health expenditure (% of GGP)                                        0
# Domestic credit provided by financial sector (% of GGP)                      0
#                                                                             ..
# galaxy                                                                       0
# index                                                                        0
# train_test                                                                   0
# y                                                                            0
# galplusyr                                                                    0
# Length: 83, dtype: int64

# %%
[col for col in df_a_sort.columns if col not in df_combined.columns]
# Out:
# ['index', 'galplusyr']

# %%
df_a_sort.drop(columns=['index', 'galplusyr'],inplace=True)

# %%
df_a_sort_dum = pd.get_dummies(df_a_sort, columns=['galaxy'])

# %%
df_a_sort_dum[df_a_sort_dum["train_test"]=='train']
# Out:
#       Adjusted net savings   \
# 1820              20.990668
# 2003              20.990668
# 2198              20.990668
# 2416              20.990668
# 2606              20.990668
# ...                     ...
# 959                4.618121
# 1082              20.990668
# 1283              20.990668
# 1620              20.990668
# 1722              20.990668
#
#       Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 1820                                          84.826552
# 2003                                         109.537364
# 2198                                         109.537364
# 2416                                         109.537364
# 2606                                         109.537364
# ...                                                 ...
# 959                                          270.067153
# 1082                                         109.537364
# 1283                                         109.537364
# ...

# %%
df = df_a_sort_dum[df_a_sort_dum["train_test"]=='train'].copy()
df_test = df_a_sort_dum[df_a_sort_dum["train_test"]=='test'].copy()
df.drop('train_test',axis=1,inplace=True)
df_test.drop('train_test',axis=1,inplace=True)

# %%
df.sort_index(inplace=True)
df_test.sort_index(inplace=True)

# %%
df_test
# Out:
#      Adjusted net savings   \
# 0                20.990668
# 1                20.990668
# 2                20.990668
# 3                20.990668
# 4                20.990668
# ..                     ...
# 885              20.990668
# 886              20.990668
# 887              20.990668
# 888              20.990668
# 889              20.990668
#
#      Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 0                                           109.537364
# 1                                           109.537364
# 2                                           109.537364
# 3                                           109.537364
# 4                                           162.451451
# ..                                                 ...
# 885                                         109.537364
# 886                                         109.537364
# 887                                         109.537364
# ...

# %%
df.to_csv("train_timeseriesimputed.csv",index=False)
df_test.to_csv("test_timeseriesimputed.csv",index=False)

# %% [markdown]
# # Testing ground

# %%
pd.DataFrame(results_df.isna().sum()).sort_values(by=0,ascending=False)
# Out:
#                                                      0
# date                                                81
# Creature Immunodeficiency Disease prevalence, a...  54
# Private galaxy capital flows (% of GGP)             54
# y                                                   15
# Population using at least basic sanitation serv...   0
# ...                                                 ..
# Intergalactic Development Index (IDI), Rank          0
# Intergalactic Development Index (IDI)                0
# Infants lacking immunization, red hot disease (...   0
# Infants lacking immunization, Combination Vacci...   0
# Maternal mortality ratio (deaths per 100,000 li...   0
#
# [83 rows x 1 columns]

# %%
df_combined[df_combined['galaxy']=='Virgo I']['Adjusted net savings ']
# Out:
# 2       21.151265
# 309           NaN
# 364           NaN
# 635           NaN
# 897           NaN
# 968           NaN
# 1130          NaN
# 1292          NaN
# 1487          NaN
# 1678          NaN
# 1975          NaN
# 2102          NaN
# 2217          NaN
# 2373          NaN
# 2641          NaN
# 2717          NaN
# 2974          NaN
# 3136          NaN
# 3184          NaN
# 3265          NaN
# 3332          NaN
# 3472          NaN
# 3578          NaN
# 3842          NaN
# 4             NaN
# 21            NaN
# 67            NaN
# Name: Adjusted net savings , dtype: float64

# %%
pd.DataFrame(df_temp_1.isna().sum())
# Out:
#                                                      0
# index                                                0
# Adjusted net savings                                 0
# Adolescent birth rate (births per 1,000 female ...   0
# Current health expenditure (% of GGP)                0
# Domestic credit provided by financial sector (%...   0
# ...                                                 ..
# Creature Immunodeficiency Disease prevalence, a...  27
# galaxy                                               0
# train_test                                           0
# y                                                    8
# Private galaxy capital flows (% of GGP)             27
#
# [82 rows x 1 columns]

# %%
results_df['Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total'].isna().sum()
# Out:
# 1239

# %%
results_df.sort_values(by='Creature Immunodeficiency Disease prevalence, adult (% ages 15-49), total',ascending=False).head(100)
# Out:
#     Adjusted net savings   \
# 24              35.145064
# 20               6.496045
# 22              24.808296
# 23              31.512148
# 10              53.011804
# ..                    ...
# 11              21.147573
# 12              17.184165
# 20               5.360955
# 13              21.139723
# 14              21.143589
#
#     Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 24                                         109.227364
# 20                                         182.990652
# 22                                         146.999235
# 23                                         159.077888
# 10                                         117.235865
# ..                                                ...
# 11                                         225.422648
# 12                                         221.909154
# 20                                         161.882808
# 13                                         218.450422
# ...

# %%
results_df.shape
# Out:
# (4809, 83)

# %%
df_combined
# Out:
#      Adjusted net savings   \
# 0                      NaN
# 1                19.177926
# 2                21.151265
# 3                      NaN
# 4                      NaN
# ..                     ...
# 885                    NaN
# 886                    NaN
# 887                    NaN
# 888                    NaN
# 889                    NaN
#
#      Adolescent birth rate (births per 1,000 female creatures ages 15-19)  \
# 0                                           174.617899
# 1                                           109.892385
# 2                                           230.573666
# 3                                           198.971328
# 4                                            61.008654
# ..                                                 ...
# 885                                                NaN
# 886                                                NaN
# 887                                                NaN
# ...

# %%
results_df.dtypes.unique()
# Out:
# array([dtype('float64'), dtype('O')], dtype=object)
